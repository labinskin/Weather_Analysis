# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Open Weather API Call
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create a set of random latitudes and longitudes combos
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
#Create an empyt list to hold weather data
city_data=[]
#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count=1
set_count=1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather=requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        #Append the city information into the city data list
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind,
                          "Current Description":city_description})
        
#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | caernarfon
# Processing Record 2 of Set 1 | george town
# Processing Record 3 of Set 1 | aldan
# Processing Record 4 of Set 1 | partizanskoye
# Processing Record 5 of Set 1 | san andres
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | auki
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | forest
# Processing Record 13 of Set 1 | boda
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | snasa
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | dryden
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | kamenka
# Processing Record 21 of Set 1 | peniche
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | sao joao da barra
# Processing Record 26 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | bonavista
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | bima
# Processing Record 32 of Set 1 | lewistown
# Processing Record 33 of Set 1 | jabinyanah
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | mochudi
# Processing Record 36 of Set 1 | xiantao
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | filadelfia
# Processing Record 39 of Set 1 | bilma
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | flinders
# Processing Record 44 of Set 1 | bereda
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | bosaso
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | muyezerskiy
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | san patricio
# Processing Record 5 of Set 2 | vostok
# Processing Record 6 of Set 2 | dauphin
# Processing Record 7 of Set 2 | buala
# Processing Record 8 of Set 2 | necochea
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | aklavik
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | hofn
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | olafsvik
# Processing Record 15 of Set 2 | maumere
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | addis zemen
# City not found. Skipping...
# Processing Record 22 of Set 2 | pontes e lacerda
# Processing Record 23 of Set 2 | mehamn
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | pandan
# Processing Record 29 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | richards bay
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | huilong
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | labuhan
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | nemuro
# Processing Record 39 of Set 2 | takoradi
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | ixtapa
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | aldama
# Processing Record 46 of Set 2 | ostrovnoy
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | barra do garcas
# Processing Record 49 of Set 2 | kushmurun
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | riachao das neves
# Processing Record 2 of Set 3 | zambezi
# Processing Record 3 of Set 3 | tank
# Processing Record 4 of Set 3 | salvacion
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | labytnangi
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | harer
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | tabas
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | bilibino
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | srednekolymsk
# Processing Record 17 of Set 3 | vestmannaeyjar
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | hibbing
# Processing Record 20 of Set 3 | lubu
# Processing Record 21 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | port hedland
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | cam ranh
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | anju
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | wagar
# Processing Record 34 of Set 3 | sidney
# Processing Record 35 of Set 3 | kalabugao
# City not found. Skipping...
# Processing Record 36 of Set 3 | banda aceh
# Processing Record 37 of Set 3 | essex
# Processing Record 38 of Set 3 | cuamba
# Processing Record 39 of Set 3 | tyrma
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | vardo
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | tyubuk
# Processing Record 45 of Set 3 | nyakahanga
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | yamada
# Processing Record 48 of Set 3 | jiangyou
# Processing Record 49 of Set 3 | yako
# Processing Record 50 of Set 3 | phalombe
# Processing Record 1 of Set 4 | altea
# Processing Record 2 of Set 4 | arman
# Processing Record 3 of Set 4 | morgan city
# Processing Record 4 of Set 4 | teguldet
# Processing Record 5 of Set 4 | qaqortoq
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | kapit
# Processing Record 9 of Set 4 | zeya
# Processing Record 10 of Set 4 | ferkessedougou
# Processing Record 11 of Set 4 | liuzhou
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | saint-pierre
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | bad neuenahr-ahrweiler
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | boyolangu
# Processing Record 19 of Set 4 | gizo
# Processing Record 20 of Set 4 | taicheng
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | norman wells
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | machilipatnam
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | gobabis
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 4 | moba
# Processing Record 30 of Set 4 | simnas
# Processing Record 31 of Set 4 | udachnyy
# Processing Record 32 of Set 4 | salinopolis
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | cherskiy
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | kamen-rybolov
# Processing Record 37 of Set 4 | cairns
# Processing Record 38 of Set 4 | piracuruca
# Processing Record 39 of Set 4 | sao felix do xingu
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | kutum
# Processing Record 44 of Set 4 | rehoboth
# Processing Record 45 of Set 4 | pravda
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | lokosovo
# Processing Record 50 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | shenjiamen
# Processing Record 4 of Set 5 | poum
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 5 | bolotnoye
# Processing Record 7 of Set 5 | rawson
# Processing Record 8 of Set 5 | qandala
# Processing Record 9 of Set 5 | weihe
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | geraldton
# Processing Record 13 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 5 | komsomolskiy
# Processing Record 15 of Set 5 | southbridge
# Processing Record 16 of Set 5 | arteaga
# Processing Record 17 of Set 5 | rudkobing
# Processing Record 18 of Set 5 | jucurutu
# Processing Record 19 of Set 5 | alice springs
# Processing Record 20 of Set 5 | biak
# Processing Record 21 of Set 5 | zenica
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | vila franca do campo
# Processing Record 25 of Set 5 | leiyang
# Processing Record 26 of Set 5 | borgarnes
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | tiznit
# Processing Record 29 of Set 5 | harrison
# Processing Record 30 of Set 5 | senanga
# Processing Record 31 of Set 5 | cascais
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | nara
# Processing Record 34 of Set 5 | tiarei
# Processing Record 35 of Set 5 | erzin
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | zhigansk
# Processing Record 39 of Set 5 | luwuk
# Processing Record 40 of Set 5 | ko samui
# Processing Record 41 of Set 5 | maldonado
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | korsor
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | tadine
# Processing Record 48 of Set 5 | jamame
# Processing Record 49 of Set 5 | palmer
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | waingapu
# Processing Record 3 of Set 6 | lacson
# Processing Record 4 of Set 6 | fukue
# Processing Record 5 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 6 | fairbanks
# Processing Record 7 of Set 6 | asau
# Processing Record 8 of Set 6 | madang
# Processing Record 9 of Set 6 | kaeo
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | iquique
# Processing Record 12 of Set 6 | kaspiyskiy
# Processing Record 13 of Set 6 | benton harbor
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | rundu
# Processing Record 17 of Set 6 | voznesenye
# Processing Record 18 of Set 6 | olden
# Processing Record 19 of Set 6 | tjome
# Processing Record 20 of Set 6 | belaya gora
# Processing Record 21 of Set 6 | mahebourg
# Processing Record 22 of Set 6 | puro
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | safford
# Processing Record 27 of Set 6 | hirado
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | maghar
# Processing Record 30 of Set 6 | hami
# Processing Record 31 of Set 6 | nerchinskiy zavod
# Processing Record 32 of Set 6 | nurota
# Processing Record 33 of Set 6 | robertsport
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | houma
# Processing Record 36 of Set 6 | suchindram
# Processing Record 37 of Set 6 | boa vista
# Processing Record 38 of Set 6 | esperance
# Processing Record 39 of Set 6 | quebec
# Processing Record 40 of Set 6 | pandharpur
# Processing Record 41 of Set 6 | harper
# Processing Record 42 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | gorontalo
# Processing Record 45 of Set 6 | savannah bight
# Processing Record 46 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 47 of Set 6 | barreirinha
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | strezhevoy
# Processing Record 50 of Set 6 | vezirkopru
# Processing Record 1 of Set 7 | bud
# Processing Record 2 of Set 7 | kahului
# Processing Record 3 of Set 7 | chapais
# Processing Record 4 of Set 7 | ensenada
# Processing Record 5 of Set 7 | tuktoyaktuk
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | vrangel
# Processing Record 8 of Set 7 | sterling
# Processing Record 9 of Set 7 | gambela
# Processing Record 10 of Set 7 | luanda
# Processing Record 11 of Set 7 | la rioja
# Processing Record 12 of Set 7 | doha
# Processing Record 13 of Set 7 | nacala
# Processing Record 14 of Set 7 | torres
# Processing Record 15 of Set 7 | burriana
# Processing Record 16 of Set 7 | xining
# Processing Record 17 of Set 7 | kocs
# Processing Record 18 of Set 7 | alexandria
# Processing Record 19 of Set 7 | tabou
# Processing Record 20 of Set 7 | ginir
# Processing Record 21 of Set 7 | samarai
# Processing Record 22 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | bandhi
# Processing Record 24 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 7 | umea
# Processing Record 26 of Set 7 | esil
# Processing Record 27 of Set 7 | padang
# Processing Record 28 of Set 7 | la ronge
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | guelengdeng
# City not found. Skipping...
# Processing Record 31 of Set 7 | kaitangata
# Processing Record 32 of Set 7 | acarau
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | sironko
# Processing Record 36 of Set 7 | soyo
# Processing Record 37 of Set 7 | noumea
# Processing Record 38 of Set 7 | port lincoln
# Processing Record 39 of Set 7 | lasa
# Processing Record 40 of Set 7 | kushiro
# Processing Record 41 of Set 7 | muros
# Processing Record 42 of Set 7 | andenes
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | laguna
# Processing Record 45 of Set 7 | olinda
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | ketchikan
# Processing Record 48 of Set 7 | vagur
# Processing Record 49 of Set 7 | mwene-ditu
# Processing Record 50 of Set 7 | tucuma
# Processing Record 1 of Set 8 | clarksburg
# Processing Record 2 of Set 8 | dabou
# Processing Record 3 of Set 8 | mwense
# Processing Record 4 of Set 8 | karangampel
# Processing Record 5 of Set 8 | waddan
# Processing Record 6 of Set 8 | eyrarbakki
# Processing Record 7 of Set 8 | malakal
# Processing Record 8 of Set 8 | mozarlandia
# Processing Record 9 of Set 8 | shihezi
# Processing Record 10 of Set 8 | chichi
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | biscarrosse
# Processing Record 13 of Set 8 | beaufort
# Processing Record 14 of Set 8 | burlington
# Processing Record 15 of Set 8 | voloshka
# Processing Record 16 of Set 8 | hoi an
# Processing Record 17 of Set 8 | fairmount
# Processing Record 18 of Set 8 | mossendjo
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | tifton
# Processing Record 21 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 8 | gazanjyk
# Processing Record 23 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 8 | kargil
# Processing Record 25 of Set 8 | guerrero negro
# Processing Record 26 of Set 8 | poienile de sub munte
# Processing Record 27 of Set 8 | morwa
# Processing Record 28 of Set 8 | waipawa
# Processing Record 29 of Set 8 | shache
# Processing Record 30 of Set 8 | najran
# Processing Record 31 of Set 8 | saryg-sep
# Processing Record 32 of Set 8 | touros
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | vaitape
# Processing Record 35 of Set 8 | puntarenas
# Processing Record 36 of Set 8 | pochutla
# Processing Record 37 of Set 8 | soto la marina
# Processing Record 38 of Set 8 | high level
# Processing Record 39 of Set 8 | kalaikunda
# Processing Record 40 of Set 8 | berlevag
# Processing Record 41 of Set 8 | bathsheba
# Processing Record 42 of Set 8 | muscat
# Processing Record 43 of Set 8 | bethel
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | doka
# Processing Record 46 of Set 8 | katherine
# Processing Record 47 of Set 8 | nouakchott
# Processing Record 48 of Set 8 | broome
# Processing Record 49 of Set 8 | baronissi
# Processing Record 50 of Set 8 | zemio
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | cotonou
# Processing Record 3 of Set 9 | charsadda
# Processing Record 4 of Set 9 | sol-iletsk
# Processing Record 5 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 9 | louis trichardt
# Processing Record 7 of Set 9 | corn island
# Processing Record 8 of Set 9 | karpuninskiy
# City not found. Skipping...
# Processing Record 9 of Set 9 | soc trang
# Processing Record 10 of Set 9 | rosetta
# Processing Record 11 of Set 9 | turukhansk
# Processing Record 12 of Set 9 | lagunas
# Processing Record 13 of Set 9 | valparaiso
# Processing Record 14 of Set 9 | haines junction
# Processing Record 15 of Set 9 | alvaraes
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | ipixuna
# Processing Record 18 of Set 9 | gonbad-e qabus
# Processing Record 19 of Set 9 | challans
# Processing Record 20 of Set 9 | pasighat
# Processing Record 21 of Set 9 | derzhavinsk
# Processing Record 22 of Set 9 | ranong
# Processing Record 23 of Set 9 | tezu
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | govindgarh
# Processing Record 26 of Set 9 | havelock
# Processing Record 27 of Set 9 | taldom
# Processing Record 28 of Set 9 | kotelnich
# Processing Record 29 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 30 of Set 9 | ust-tsilma
# Processing Record 31 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | sorland
# Processing Record 34 of Set 9 | leningradskiy
# Processing Record 35 of Set 9 | vernon
# Processing Record 36 of Set 9 | tateyama
# Processing Record 37 of Set 9 | sonepur
# Processing Record 38 of Set 9 | borogontsy
# Processing Record 39 of Set 9 | ambon
# Processing Record 40 of Set 9 | cozumel
# Processing Record 41 of Set 9 | urucara
# Processing Record 42 of Set 9 | bid
# City not found. Skipping...
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | kedrovyy
# Processing Record 45 of Set 9 | erhlin
# City not found. Skipping...
# Processing Record 46 of Set 9 | bintulu
# Processing Record 47 of Set 9 | hope
# Processing Record 48 of Set 9 | obihiro
# Processing Record 49 of Set 9 | jundia
# Processing Record 50 of Set 9 | juneau
# Processing Record 1 of Set 10 | verkhnevilyuysk
# Processing Record 2 of Set 10 | quelimane
# Processing Record 3 of Set 10 | kano
# Processing Record 4 of Set 10 | mountain home
# Processing Record 5 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 10 | capitao poco
# Processing Record 7 of Set 10 | constantine
# Processing Record 8 of Set 10 | karibib
# Processing Record 9 of Set 10 | hokitika
# Processing Record 10 of Set 10 | yiyang
# Processing Record 11 of Set 10 | cap-aux-meules
# Processing Record 12 of Set 10 | ashland
# Processing Record 13 of Set 10 | arys
# Processing Record 14 of Set 10 | tornio
# Processing Record 15 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 10 | semey
# City not found. Skipping...
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | thinadhoo
# Processing Record 19 of Set 10 | jutai
# Processing Record 20 of Set 10 | ayan
# Processing Record 21 of Set 10 | koumac
# Processing Record 22 of Set 10 | paamiut
# Processing Record 23 of Set 10 | pringsewu
# Processing Record 24 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 10 | atambua
# Processing Record 26 of Set 10 | miramar
# Processing Record 27 of Set 10 | razdolnoye
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | ahipara
# Processing Record 30 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | sakata
# Processing Record 33 of Set 10 | yatou
# Processing Record 34 of Set 10 | sandakan
# Processing Record 35 of Set 10 | paita
# Processing Record 36 of Set 10 | akdagmadeni
# Processing Record 37 of Set 10 | lakota
# Processing Record 38 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 10 | rio negro
# Processing Record 40 of Set 10 | port-gentil
# Processing Record 41 of Set 10 | mulege
# Processing Record 42 of Set 10 | baracoa
# Processing Record 43 of Set 10 | pisco
# Processing Record 44 of Set 10 | fomboni
# Processing Record 45 of Set 10 | alyangula
# Processing Record 46 of Set 10 | bongandanga
# Processing Record 47 of Set 10 | bar harbor
# Processing Record 48 of Set 10 | visby
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | north bend
# Processing Record 1 of Set 11 | meadow lake
# Processing Record 2 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 3 of Set 11 | yoichi
# Processing Record 4 of Set 11 | ancud
# Processing Record 5 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 11 | krasnyy klyuch
# Processing Record 7 of Set 11 | guilin
# Processing Record 8 of Set 11 | chara
# Processing Record 9 of Set 11 | saint-francois
# Processing Record 10 of Set 11 | vila
# Processing Record 11 of Set 11 | huadian
# Processing Record 12 of Set 11 | bakel
# Processing Record 13 of Set 11 | eldorado
# Processing Record 14 of Set 11 | rincon
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | koungheul
# Processing Record 17 of Set 11 | broken hill
# Processing Record 18 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 11 | empalme
# Processing Record 21 of Set 11 | gombong
# Processing Record 22 of Set 11 | sungaipenuh
# Processing Record 23 of Set 11 | kijang
# Processing Record 24 of Set 11 | kalispell
# Processing Record 25 of Set 11 | alugan
# Processing Record 26 of Set 11 | forestville
# Processing Record 27 of Set 11 | mwandiga
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 11 | troitskoye
# Processing Record 31 of Set 11 | acari
# Processing Record 32 of Set 11 | grindavik
# Processing Record 33 of Set 11 | opuwo
# Processing Record 34 of Set 11 | newport
# Processing Record 35 of Set 11 | mindelo
# Processing Record 36 of Set 11 | storforshei
# Processing Record 37 of Set 11 | freetown
# Processing Record 38 of Set 11 | geilo
# Processing Record 39 of Set 11 | balsas
# Processing Record 40 of Set 11 | portree
# Processing Record 41 of Set 11 | santa rosa
# Processing Record 42 of Set 11 | solnechnyy
# Processing Record 43 of Set 11 | erdenet
# Processing Record 44 of Set 11 | tianpeng
# Processing Record 45 of Set 11 | santa cruz
# Processing Record 46 of Set 11 | khadyzhensk
# Processing Record 47 of Set 11 | williams lake
# Processing Record 48 of Set 11 | cabedelo
# Processing Record 49 of Set 11 | lata
# Processing Record 50 of Set 11 | dunedin
# Processing Record 1 of Set 12 | sibu
# Processing Record 2 of Set 12 | machinga
# Processing Record 3 of Set 12 | guane
# Processing Record 4 of Set 12 | leeton
# Processing Record 5 of Set 12 | husavik
# Processing Record 6 of Set 12 | camabatela
# Processing Record 7 of Set 12 | osmena
# Processing Record 8 of Set 12 | mangrol
# Processing Record 9 of Set 12 | khandyga
# Processing Record 10 of Set 12 | humberto de campos
# Processing Record 11 of Set 12 | ati
# Processing Record 12 of Set 12 | buin
# Processing Record 13 of Set 12 | kargat
# Processing Record 14 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 12 | hanna
# Processing Record 17 of Set 12 | ponta delgada
# Processing Record 18 of Set 12 | korla
# Processing Record 19 of Set 12 | zhoucheng
# Processing Record 20 of Set 12 | sabha
# Processing Record 21 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 12 | matay
# Processing Record 24 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 25 of Set 12 | verkhnyaya khava
# Processing Record 26 of Set 12 | green river
# Processing Record 27 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 12 | sisimiut
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | soe
# Processing Record 31 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 12 | leskovik
# Processing Record 34 of Set 12 | kozmodemyansk
# Processing Record 35 of Set 12 | severomuysk
# Processing Record 36 of Set 12 | bahia honda
# Processing Record 37 of Set 12 | camopi
# Processing Record 38 of Set 12 | mezen
# Processing Record 39 of Set 12 | amot
# Processing Record 40 of Set 12 | kasongo-lunda
# Processing Record 41 of Set 12 | tolmachevo
# Processing Record 42 of Set 12 | wajima
# Processing Record 43 of Set 12 | sabang
# Processing Record 44 of Set 12 | pathardi
# Processing Record 45 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 46 of Set 12 | leshukonskoye
# Processing Record 47 of Set 12 | mineiros
# Processing Record 48 of Set 12 | provideniya
# Processing Record 49 of Set 12 | omsukchan
# Processing Record 50 of Set 12 | pangai
# Processing Record 1 of Set 13 | petatlan
# Processing Record 2 of Set 13 | elizabeth city
# Processing Record 3 of Set 13 | paka
# Processing Record 4 of Set 13 | shirokiy
# Processing Record 5 of Set 13 | port macquarie
# Processing Record 6 of Set 13 | palu
# Processing Record 7 of Set 13 | namatanai
# Processing Record 8 of Set 13 | vanavara
# Processing Record 9 of Set 13 | bubaque
# Processing Record 10 of Set 13 | baykit
# Processing Record 11 of Set 13 | halifax
# Processing Record 12 of Set 13 | talnakh
# Processing Record 13 of Set 13 | aykhal
# Processing Record 14 of Set 13 | muzhi
# Processing Record 15 of Set 13 | khorixas
# Processing Record 16 of Set 13 | pitimbu
# Processing Record 17 of Set 13 | trelew
# Processing Record 18 of Set 13 | mandan
# Processing Record 19 of Set 13 | ngunguru
# Processing Record 20 of Set 13 | saiha
# Processing Record 21 of Set 13 | faanui
# Processing Record 22 of Set 13 | whitehorse
# Processing Record 23 of Set 13 | axim
# Processing Record 24 of Set 13 | chincha alta
# Processing Record 25 of Set 13 | honningsvag
# Processing Record 26 of Set 13 | ilheus
# Processing Record 27 of Set 13 | ormara
# Processing Record 28 of Set 13 | vao
# Processing Record 29 of Set 13 | dimbokro
# Processing Record 30 of Set 13 | trairi
# Processing Record 31 of Set 13 | tayshet
# Processing Record 32 of Set 13 | portland
# Processing Record 33 of Set 13 | otavi
# Processing Record 34 of Set 13 | launceston
# Processing Record 35 of Set 13 | digby
# Processing Record 36 of Set 13 | tessalit
# Processing Record 37 of Set 13 | beloha
# Processing Record 38 of Set 13 | piriyapatna
# Processing Record 39 of Set 13 | shenzhen
# Processing Record 40 of Set 13 | buchanan
# Processing Record 41 of Set 13 | kalmunai
# Processing Record 42 of Set 13 | trinidad
# Processing Record 43 of Set 13 | dwarka
# Processing Record 44 of Set 13 | lubao
# Processing Record 45 of Set 13 | ambilobe
# Processing Record 46 of Set 13 | torbat-e jam
# Processing Record 47 of Set 13 | ossora
# Processing Record 48 of Set 13 | terlicko
# City not found. Skipping...
# Processing Record 49 of Set 13 | marzuq
# Processing Record 50 of Set 13 | mount gambier
# Processing Record 1 of Set 14 | the valley
# Processing Record 2 of Set 14 | lufilufi
# Processing Record 3 of Set 14 | inverness
# Processing Record 4 of Set 14 | bartlesville
# Processing Record 5 of Set 14 | sulangan
# Processing Record 6 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 14 | zarubino
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | santa isabel do rio negro
# Processing Record 10 of Set 14 | pangody
# Processing Record 11 of Set 14 | port pirie
# Processing Record 12 of Set 14 | lethem
# Processing Record 13 of Set 14 | okato
# Processing Record 14 of Set 14 | pemangkat
# Processing Record 15 of Set 14 | gravdal
# Processing Record 16 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 14 | otane
# Processing Record 18 of Set 14 | kyra
# Processing Record 19 of Set 14 | honiara
# Processing Record 20 of Set 14 | werda
# Processing Record 21 of Set 14 | galle
# Processing Record 22 of Set 14 | banff
# Processing Record 23 of Set 14 | noyabrsk
# Processing Record 24 of Set 14 | laurel
# Processing Record 25 of Set 14 | manggar
# Processing Record 26 of Set 14 | avera
# Processing Record 27 of Set 14 | at-bashi
# Processing Record 28 of Set 14 | egvekinot
# Processing Record 29 of Set 14 | chhatarpur
# Processing Record 30 of Set 14 | uruzgan
# Processing Record 31 of Set 14 | erice
# Processing Record 32 of Set 14 | kautokeino
# Processing Record 33 of Set 14 | saint-louis
# Processing Record 34 of Set 14 | guatire
# Processing Record 35 of Set 14 | gander
# Processing Record 36 of Set 14 | mayo
# Processing Record 37 of Set 14 | kavaratti
# Processing Record 38 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | veraval
# Processing Record 40 of Set 14 | kargasok
# Processing Record 41 of Set 14 | nampula
# Processing Record 42 of Set 14 | quatre cocos
# Processing Record 43 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 14 | plettenberg bay
# Processing Record 45 of Set 14 | rabo de peixe
# Processing Record 46 of Set 14 | akyab
# Processing Record 47 of Set 14 | oussouye
# Processing Record 48 of Set 14 | swan hill
# Processing Record 49 of Set 14 | kalavrita
# City not found. Skipping...
# Processing Record 50 of Set 14 | dhidhdhoo
# Processing Record 1 of Set 15 | alberton
# Processing Record 2 of Set 15 | kazachinskoye
# Processing Record 3 of Set 15 | angoche
# Processing Record 4 of Set 15 | aasiaat
# Processing Record 5 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 15 | zykovo
# Processing Record 7 of Set 15 | myaundzha
# Processing Record 8 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 15 | medicine hat
# Processing Record 10 of Set 15 | kusk
# City not found. Skipping...
# Processing Record 11 of Set 15 | springbok
# Processing Record 12 of Set 15 | baglung
# Processing Record 13 of Set 15 | yablonovo
# Processing Record 14 of Set 15 | upington
# Processing Record 15 of Set 15 | libenge
# Processing Record 16 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 15 | cayenne
# Processing Record 18 of Set 15 | kropotkin
# Processing Record 19 of Set 15 | boa viagem
# Processing Record 20 of Set 15 | mopti
# Processing Record 21 of Set 15 | kargapolye
# City not found. Skipping...
# Processing Record 22 of Set 15 | napanee
# Processing Record 23 of Set 15 | sozopolis
# City not found. Skipping...
# Processing Record 24 of Set 15 | nkhotakota
# Processing Record 25 of Set 15 | smithers
# Processing Record 26 of Set 15 | kiunga
# Processing Record 27 of Set 15 | durazno
# Processing Record 28 of Set 15 | krasnoselkup
# Processing Record 29 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 15 | kirakira
# Processing Record 31 of Set 15 | sioux lookout
# Processing Record 32 of Set 15 | vanimo
# Processing Record 33 of Set 15 | qarqin
# Processing Record 34 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 35 of Set 15 | hearst
# Processing Record 36 of Set 15 | sagua la grande
# Processing Record 37 of Set 15 | monze
# Processing Record 38 of Set 15 | laje
# Processing Record 39 of Set 15 | raga
# Processing Record 40 of Set 15 | prainha
# Processing Record 41 of Set 15 | jalu
# Processing Record 42 of Set 15 | atherton
# Processing Record 43 of Set 15 | sayyan
# Processing Record 44 of Set 15 | ulladulla
# Processing Record 45 of Set 15 | suzun
# Processing Record 46 of Set 15 | oneonta
# Processing Record 47 of Set 15 | bichura
# Processing Record 48 of Set 15 | toamasina
# Processing Record 49 of Set 15 | saint-joseph
# Processing Record 50 of Set 15 | alekseyevka
# Processing Record 1 of Set 16 | lucea
# Processing Record 2 of Set 16 | kurumkan
# Processing Record 3 of Set 16 | osypenko
# Processing Record 4 of Set 16 | guarapari
# Processing Record 5 of Set 16 | anori
# Processing Record 6 of Set 16 | alta floresta
# Processing Record 7 of Set 16 | rancho cordova
# Processing Record 8 of Set 16 | milkovo
# Processing Record 9 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 16 | ternate
# Processing Record 11 of Set 16 | kitui
# Processing Record 12 of Set 16 | rabaul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert array of dictionaries into Pandas DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Caernarfon      GB  53.1413   -4.2702     60.71        40          90
# 1    George Town      MY   5.4112  100.3354     82.33        78          20
# 2          Aldan      RU  58.6031  125.3894     29.91        97         100
# 3  Partizanskoye      RU  55.5006   94.3900     47.12        51         100
# 4     San Andres      CO  12.5847  -81.7006     84.22        74          20
# 5       Tasiilaq      GL  65.6145  -37.6368     37.56        80         100
# 6   Puerto Ayora      EC  -0.7393  -90.3518     68.56        92          95
# 7           Auki      SB  -8.7676  160.7034     88.00        60          89
# 8         Atuona      PF  -9.8000 -139.0333     77.72        68           4
# 9         Forest      US  37.3638  -79.2897     53.65        58          20
#
#    Wind Speed Current Description
# 0       25.32     overcast clouds
# 1        2.30          few clouds
# 2       10.96                snow
# 3       21.99     overcast clouds
# 4        8.05          few clouds
# 5        8.70     overcast clouds
# 6        3.00     overcast clouds
# 7        4.88     overcast clouds
# 8       13.20           clear sky
# 9        1.01          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
